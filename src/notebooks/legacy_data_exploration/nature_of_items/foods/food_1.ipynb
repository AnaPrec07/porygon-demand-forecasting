# %% [markdown]
# # Nature of Items - Foods 1
#
# This notebook looks to understand better the behavior of individual items in Foods 1.

# %% [markdown]
# ## 0.1 Pricing
#
# This section looks for patterns in
# 1. Price over time
# 2. Price changes and promotions
# 3. Price elasticity

# %% [markdown]
# ## 0.2 Weather
#
# This section looks for pattenrs of daily weather variables on daily sales.

# %% [markdown]
# ## 0.3 Bulk
# This section looks for patterns in:
# 1. Daily sales coefficient of variation

# %% [markdown]
# ## 0.4 SNAP
#
# This secion looks if SNAP days have an impact on sales
